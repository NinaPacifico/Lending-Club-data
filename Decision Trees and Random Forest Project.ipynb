# %% [markdown]
# # Decision Tree and Random Forest Project
#
# This project explores the publicly available data from [LendingClub.com](www.lendingclub.com). Lending Club connects people who need money with investors.
#
# We want to create a model that helps investors to invest in people who showed a profile of having a high probability of paying you back.
#
#
# We use lending data from 2007-2010 and try to classify and predict whether or not the borrower paid back their loan in full.
#
# The data set shows:
# * credit.policy: 1 if the customer meets the credit underwriting criteria of       LendingClub.com, and 0 otherwise.
# * purpose: The purpose of the loan (credit_card, debt_consolidation, educational, major_purchase, small_business and all_other).
# * int.rate: The interest rate of the loan, as a proportion. Borrowers judged by LendingClub.com to be more risky are assigned higher interest rates.
# * installment: The monthly installments owed by the borrower if the loan is funded.
# * log.annual.inc: The natural log of the self-reported annual income of the borrower.
# * dti: The debt-to-income ratio of the borrower (amount of debt divided by annual income).
# * fico: The FICO credit score of the borrower.
# * days.with.cr.line: The number of days the borrower has had a credit line.
# * revol.bal: The borrower's revolving balance (amount unpaid at the end of the credit card billing cycle).
# * revol.util: The borrower's revolving line utilization rate (the amount of the credit line used relative to total credit available).
# * inq.last.6mths: The borrower's number of inquiries by creditors in the last 6 months.
# * delinq.2yrs: The number of times the borrower had been 30+ days past due on a payment in the past 2 years.
# * pub.rec: The borrower's number of derogatory public records (bankruptcy filings, tax liens, or judgments).

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data

# %%
df = pd.read_csv('loan_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(10,8))
plt.grid(True)
plt.hist(df[df['credit.policy']==1]['fico'],bins=30,alpha=0.8,color='lightpink',label='credit.policy = 1')
plt.hist(df[df['credit.policy']==0]['fico'],bins=30,alpha=0.8,color='cornflowerblue',label='credit.policy = 0')
plt.legend()
plt.xlabel('FICO')
plt.ylabel('total number')
plt.title('Histogram showing the FICO credit store of the borrowers group by the credit critirea',size=15)
# Out:
# Text(0.5,1,'Histogram showing the FICO credit store of the borrowers group by the credit critirea')

# %%
plt.figure(figsize=(10,8))
plt.grid(True)
plt.hist(df[df['not.fully.paid']==0]['fico'],bins=30,alpha=0.8,color='lightpink',label='fully paid')
plt.hist(df[df['not.fully.paid']==1]['fico'],bins=30,alpha=0.8,color='cornflowerblue',label='not fully paid')
plt.legend()
plt.xlabel('FICO')
plt.ylabel('total number')
plt.title('Histogram showing the FICO credit store of the borrowers group according to whether or not they paid back',size=15)
# Out:
# Text(0.5,1,'Histogram showing the FICO credit store of the borrowers group according to whether or not they paid back')

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(x='purpose',hue='not.fully.paid',data=df,palette="Set1")
ax.set_title('number of people who paid and who didn\'t pay back grouped by the purpose of the loan')
# Out:
# Text(0.5,1,"number of people who paid and who didn't pay back grouped by the purpose of the loan")

# %% [markdown]
# Let's see the trend between FICO score and interest rate.

# %%
sns.jointplot(x='fico',y='int.rate',data=df,space=0)

# %% [markdown]
# See if the trend differed between not.fully.paid and credit.policy.

# %%
sns.lmplot(x='fico',y='int.rate',col='not.fully.paid',data=df,hue='credit.policy',palette="Set1")

# %% [markdown]
# ## Setting up the Data

# %% [markdown]
# ### Categorical Features
#
# The **purpose** column needs to be be transformed using dummy variables so sklearn will be able to understand them.
#
# Create a list of 1 element containing the string 'purpose'. Call this list cat_feats.

# %%
cat_feats = ['purpose']

# %% [markdown]
# Create a fixed larger dataframe that has new feature columns with dummy variables. Set this dataframe as final_data.

# %%
final_data = pd.get_dummies(df,columns=cat_feats,drop_first=True)
final_data.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# ...

# %% [markdown]
# ## Train Test Split
#
# Split our data into a training set and a testing set.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(final_data.drop('not.fully.paid',axis=1), final_data['not.fully.paid'], test_size=0.3)

# %% [markdown]
# ## Training a Decision Tree Model
#
# Let's start by training a single decision tree first.

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Create an instance of DecisionTreeClassifier() called dtree and fit it to the training data.

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# ### Predictions and Evaluation of Decision Tree
# Predict if a borrower paid back and create a classification report and a confusion matrix.

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[2040  355]
#  [ 368  111]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      2395
#            1       0.24      0.23      0.23       479
#
#     accuracy                           0.75      2874
#    macro avg       0.54      0.54      0.54      2874
# weighted avg       0.75      0.75      0.75      2874

# %% [markdown]
# ## Training the Random Forest model
#
#
# Create an instance of the RandomForestClassifier class and fit it to our training data from the previous step.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ranforest = RandomForestClassifier(n_estimators=600)

# %%
ranforest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=600,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# ### Predictions and Evaluation
#
# Let's predict the y_test values and evaluate our model.

# %%
pred = ranforest.predict(X_test)

# %%
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# [[2386    9]
#  [ 472    7]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      2395
#            1       0.44      0.01      0.03       479
#
#     accuracy                           0.83      2874
#    macro avg       0.64      0.51      0.47      2874
# weighted avg       0.77      0.83      0.76      2874

# %% [markdown]
# Both models didn't do really well this might mean that more feature engineering is needed.
